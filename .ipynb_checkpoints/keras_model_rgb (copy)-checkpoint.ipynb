# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

import keras
from keras.models import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPool2D
from keras import regularizers
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model


% matplotlib inline

# %%
X = np.load("npy_dataset/X.npy")
Y = np.load("npy_dataset/Y.npy")

# %%
plt.imshow(X[0])

# %%
print("shape of X:",X.shape)
print("shape of Y:",Y.shape)
# Out:
# ('shape of X:', (5235, 100, 100, 3))
# ('shape of Y:', (5235, 11))

# %%
#Train_Test_Split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.10, random_state=1)

# %%
x_train = x_train.reshape(-1,100,100,3)
x_test = x_test.reshape(-1,100,100,3)

# %%
print("shape of x_train:",x_train.shape)
print("shape of x_test:",x_test.shape)
print("shape of y_train:",y_train.shape)
print("shape of y_test:",y_test.shape)
# Out:
# ('shape of x_train:', (4711, 100, 100, 3))
# ('shape of x_test:', (524, 100, 100, 3))
# ('shape of y_train:', (4711, 11))
# ('shape of y_test:', (524, 11))

# %%
#Our Model
def LeNet(width, height, channels, output):
    model = Sequential()
    
    #Convulation 1
    model.add(Conv2D(filters=32, kernel_size=(3,3)
                ,strides=(2,2)
                ,input_shape=(width, height, channels)))
    model.add(Activation('relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    
    #Convolution 2
    model.add(Conv2D(filters=64, kernel_size=(3,3)
                    ,strides=(1,1)
                    ,kernel_regularizer=regularizers.l2(0.01)))
    model.add(Activation('relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    
    #Convulation 3
    model.add(Conv2D(filters=100, kernel_size=(2,2)
                ,strides=(1,1)))
    model.add(Activation('relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    
    model.add(Flatten())
    
    #Hidden Layer
    model.add(Dense(100))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
    
    #Hidden Layer
    model.add(Dense(50))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
    
    model.add(Dense(output))
    
    model.add(Activation('softmax'))
    
    return model
    
#     We can also add dropout
# Total params: 300,803
# Trainable params: 300,803
# Non-trainable params: 0

#loss: 0.0366 - acc: 0.9940 - val_loss: 0.2803 - val_acc: 0.9545

# %%
# model2 = LeNet2(x_train.shape[1],x_train.shape[2],3,y_train.shape[1])

# model2.summary()

# %%
#Our Model
# def LeNet(width, height, channels, output):
#     model = Sequential()
    
#     #Convulation
#     model.add(Conv2D(filters=32, kernel_size=(3,3)
#                 ,strides=(2,2)
#                 ,input_shape=(width, height, channels)))
    
#     #ReLU Activation
#     model.add(Activation('relu'))
    
#     #Pooling
#     model.add(MaxPool2D(pool_size=(2,2)))
    
#     #Convolution
#     model.add(Conv2D(filters=64, kernel_size=(3,3)
#                     ,strides=(2,2)
#                     ,kernel_regularizer=regularizers.l2(0.01)))
    
#     #ReLU Activation
#     model.add(Activation('relu'))
    
    
#     #Pooling
#     model.add(MaxPool2D(pool_size=(2,2)))
    
#     model.add(Flatten())
    
#     #Hidden Layer
#     model.add(Dense(100))
    
#     model.add(Dropout(0.2))
    
#     model.add(Activation('relu'))
    
#     model.add(Dense(output))
    
#     model.add(Activation('softmax'))
    
#     return model
    
    #We can also add dropout
    
# Total params: 180,603
# Trainable params: 180,603
# Non-trainable params: 0

# %%
model = LeNet(x_train.shape[1],x_train.shape[2],3,y_train.shape[1])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 49, 49, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 49, 49, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 22, 22, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 100)       25700
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 100)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 100)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2500)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               250100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                561
# _________________________________________________________________
# activation_6 (Activation)    (None, 11)                0
# =================================================================
# Total params: 300,803
# Trainable params: 300,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
EPOCHS = 50

# %%
t1 = time.time()
hist_model =model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=EPOCHS)
t2=time.time()
# Out:
# Train on 4711 samples, validate on 524 samples
# Epoch 1/50
# 4711/4711 [==============================] - 14s 3ms/step - loss: 2.4496 - acc: 0.1159 - val_loss: 2.1536 - val_acc: 0.2176
# Epoch 2/50
# 4711/4711 [==============================] - 12s 3ms/step - loss: 1.8896 - acc: 0.3137 - val_loss: 1.6670 - val_acc: 0.4981
# Epoch 3/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 1.5130 - acc: 0.4768 - val_loss: 1.2507 - val_acc: 0.6183
# Epoch 4/50
# 4711/4711 [==============================] - 14s 3ms/step - loss: 1.2565 - acc: 0.5685 - val_loss: 1.0371 - val_acc: 0.7195
# Epoch 5/50
# 4711/4711 [==============================] - 14s 3ms/step - loss: 1.0351 - acc: 0.6474 - val_loss: 0.9064 - val_acc: 0.7366
# Epoch 6/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.8769 - acc: 0.7039 - val_loss: 0.7282 - val_acc: 0.8092
# Epoch 7/50
# 4711/4711 [==============================] - 14s 3ms/step - loss: 0.7373 - acc: 0.7612 - val_loss: 0.6670 - val_acc: 0.8130
# Epoch 8/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.6524 - acc: 0.7907 - val_loss: 0.6110 - val_acc: 0.8454
# Epoch 9/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.5986 - acc: 0.8111 - val_loss: 0.5578 - val_acc: 0.8492
# Epoch 10/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.5273 - acc: 0.8363 - val_loss: 0.4911 - val_acc: 0.8721
# Epoch 11/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.4757 - acc: 0.8461 - val_loss: 0.4406 - val_acc: 0.8969
# Epoch 12/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.4050 - acc: 0.8777 - val_loss: 0.4288 - val_acc: 0.8950
# Epoch 13/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.3827 - acc: 0.8822 - val_loss: 0.4291 - val_acc: 0.8874
# Epoch 14/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.3671 - acc: 0.8894 - val_loss: 0.4050 - val_acc: 0.9065
# Epoch 15/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.3312 - acc: 0.9024 - val_loss: 0.3805 - val_acc: 0.9084
# Epoch 16/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.3198 - acc: 0.9021 - val_loss: 0.3705 - val_acc: 0.9179
# Epoch 17/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0.2682 - acc: 0.9202 - val_loss: 0.3911 - val_acc: 0.9160
# Epoch 18/50
# 4711/4711 [==============================] - 14s 3ms/step - loss: 0.2497 - acc: 0.9295 - val_loss: 0.3562 - val_acc: 0.9275
# Epoch 19/50
# 4711/4711 [==============================] - 13s 3ms/step - loss: 0
50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.1209 - acc: 0.9703 - val_loss: 0.2986 - val_acc: 0.9408
# Epoch 43/50
# 4711/4711 [==============================] - 18s 4ms/step - loss: 0.0859 - acc: 0.9805 - val_loss: 0.2889 - val_acc: 0.9466
# Epoch 44/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.1210 - acc: 0.9679 - val_loss: 0.2973 - val_acc: 0.9427
# Epoch 45/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.1062 - acc: 0.9720 - val_loss: 0.2829 - val_acc: 0.9447
# Epoch 46/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.1058 - acc: 0.9745 - val_loss: 0.2514 - val_acc: 0.9523
# Epoch 47/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.0982 - acc: 0.9754 - val_loss: 0.3159 - val_acc: 0.9485
# Epoch 48/50
# 4711/4711 [==============================] - 18s 4ms/step - loss: 0.1033 - acc: 0.9743 - val_loss: 0.3339 - val_acc: 0.9351
# Epoch 49/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.0973 - acc: 0.9743 - val_loss: 0.2578 - val_acc: 0.9580
# Epoch 50/50
# 4711/4711 [==============================] - 19s 4ms/step - loss: 0.0885 - acc: 0.9788 - val_loss: 0.3152 - val_acc: 0.9447

# %%
print("time required to train ",t2-t1,"sec")
# Out:
# ('time required to train ', 817.5547850131989, 'sec')

# %%
# 100 EPOCHS 
#loss: 0.0420 - acc: 0.9885 - val_loss: 0.4082 - val_acc: 0.9050

# %%
loss = hist_model.history['loss']

plt.plot(loss)

# %%
val_acc = hist_model.history['val_acc']
val_loss = hist_model.history['val_loss']
acc = hist_model.history['acc']
loss = hist_model.history['loss']

plt_list = [acc,loss,val_acc,val_loss]
plt_label =['acc','loss','val_acc','val_loss']

# %%
fig,axes = plt.subplots(figsize=(10,10),nrows=2,ncols=2)

for i,ax in enumerate(axes.ravel()):
    
    ax.plot(plt_list[i])
    ax.set_title(plt_label[i])
    ax.set_xlabel("Epochs")
    if(i%2==0):
        ax.set_ylabel("Accuracy")
    else:
        ax.set_ylabel("Loss")

# %%
index = np.random.randint(0,206)

index
# Out:
# 152

# %%
pred = model.predict(x_test[index].reshape(1,100,100,3))

# %%
pred_index = np.argmax(pred)

pred_index
# Out:
# 9

# %%
plt.imshow(x_test[index])

# %%
def predict_img():
    index = np.random.randint(0,206)
    #print("index:",index)
    pred = model.predict(x_test[index].reshape(1,100,100,3))
    print("predicted image is:",np.argmax(pred))
    print("====showing the image======")
    plt.imshow(x_test[index],cmap='gray')

# %%
predict_img()
# Out:
# ('predicted image is:', 2)
# ====showing the image======

# %%
model.save("model_rgb_norm1.h5")

# %%
plot_model(model, to_file='images/model_norm1.png', show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-60-de0d73f100d7> in <module>()
# ----> 1 plot_model(model, to_file='images/model_norm1.png', show_shapes=True, show_layer_names=True)
#
# /home/manish/anaconda2/lib/python2.7/site-packages/keras/utils/vis_utils.pyc in plot_model(model, to_file, show_shapes, show_layer_names, rankdir)
#     130             'LR' creates a horizontal plot.
#     131     """
# --> 132     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir)
#     133     _, extension = os.path.splitext(to_file)
#     134     if not extension:
#
# /home/manish/anaconda2/lib/python2.7/site-packages/keras/utils/vis_utils.pyc in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      53     from ..models import Sequential
#      54
# ---> 55     _check_pydot()
#      56     dot = pydot.Dot()
#      57     dot.set('rankdir', rankdir)
#
# /home/manish/anaconda2/lib/python2.7/site-packages/keras/utils/vis_utils.pyc in _check_pydot()
#      18     if pydot is None:
#      19         raise ImportError(
# ---> 20             'Failed to import `pydot`. '
#      21             'Please install `pydot`. '
#      22             'For example with `pip install pydot`.')
#
# ImportError: Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.
