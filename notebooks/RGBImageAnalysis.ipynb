# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

% matplotlib inline

# %%
X = np.load("npy_dataset/X.npy")
Y = np.load("npy_dataset/Y.npy")

# %%
print X.shape
print Y.shape
# Out:
# (2415, 100, 100, 3)
# (2415, 11)

# %%
plt.imshow(X[2405],cmap='gray')
